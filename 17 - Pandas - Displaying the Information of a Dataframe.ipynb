# %% [markdown]
# # DIFFERENT WAYS OF DISPLAYING DATA

# %% [markdown]
# ### IMPORTS

# %%
import numpy as np
import pandas as pd

# %config IPCompleter.greedy = True
# Suppress scientific notation
np.set_printoptions(suppress=True)

# %%
orders = pd.read_csv('http://bit.ly/chiporders', sep='\t')
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
movies = pd.read_csv('http://bit.ly/imdbratings')
titanic = pd.read_csv('http://bit.ly/kaggletrain')

# %%
orders = pd.read_csv('http://bit.ly/chiporders', sep='\t')
orders['item_price'] = orders.item_price.str.replace('$', '').astype('float')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %% [markdown]
# ### USING GROUPBY TO DISPLAY TOTAL SUM OF EACH ORDER

# %%
orders['item_price'] = orders['item_price'].astype('float')
orders.groupby('order_id')['item_price'].sum().head()
# Out:
# order_id
# 1    11.56
# 2    16.98
# 3    12.67
# 4    21.00
# 5    13.70
# Name: item_price, dtype: float64

# %% [markdown]
# ### USING GROUPBY TO DISPLAY TOTAL SUM AND TOTAL ITEM OF EACH ORDER

# %%
orders.groupby('order_id')['item_price'].agg(['sum', 'count']).head()
# Out:
#             sum  count
# order_id
# 1         11.56      4
# 2         16.98      1
# 3         12.67      2
# 4         21.00      2
# 5         13.70      2

# %% [markdown]
# # SORT VALUES

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.sort_values('total_litres_of_pure_alcohol', ascending=False).head()
# Out:
#            country  beer_servings  spirit_servings  wine_servings  \
# 15         Belarus            142              373             42
# 98       Lithuania            343              244             56
# 3          Andorra            245              138            312
# 68         Grenada            199              438             28
# 45  Czech Republic            361              170            134
#
#     total_litres_of_pure_alcohol      continent
# 15                          14.4         Europe
# 98                          12.9         Europe
# 3                           12.4         Europe
# 68                          11.9  North America
# 45                          11.8         Europe

# %% [markdown]
# # PIVOT TABLE

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.pivot_table(index='Sex', columns='Pclass', values='Survived', aggfunc='mean')
# Out:
# Pclass         1         2         3
# Sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# ### DIVIDE STAR_RATINGS INTO 5 CATEGORIES AND COUNT THE NUMBER OF RATINGS ACROSS EACH GENRE

# %%
movies['rating_cat'] = pd.cut(movies['star_rating'], bins=5, labels=['Best', 'Good', 'Medium', 'Bad', 'Stay Away'] )
movies.pivot_table(index='rating_cat', columns='genre', values='star_rating', aggfunc='count')
# Out:
# genre       Action  Adventure  Animation  Biography  Comedy  Crime  Drama  \
# rating_cat
# Best          57.0       24.0       20.0       31.0    77.0   52.0  105.0
# Good          54.0       33.0       28.0       34.0    55.0   44.0  117.0
# Medium        18.0       14.0       13.0        9.0    21.0   20.0   46.0
# Bad            6.0        4.0        1.0        3.0     3.0    5.0   10.0
# Stay Away      1.0        NaN        NaN        NaN     NaN    3.0    NaN
#
# genre       Family  Fantasy  Film-Noir  History  Horror  Mystery  Sci-Fi  \
# rating_cat
# Best           NaN      1.0        1.0      NaN    16.0      5.0     1.0
# Good           2.0      NaN        1.0      1.0     8.0      6.0     3.0
# Medium         NaN      NaN        1.0      NaN     4.0      4.0     1.0
# Bad            NaN      NaN        NaN      NaN     1.0      1.0     NaN
# Stay Away      NaN      NaN        NaN      NaN     NaN      NaN     NaN
#
# genre       Thriller  Western
# rating_cat
# Best             3.0      1.0
# Good             2.0      3.0
# Medium           NaN      3.0
# Bad              NaN      2.0
# Stay Away        NaN      NaN
